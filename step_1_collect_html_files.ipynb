# %%
import requests # send HTTP requests to get the HTML code of a web page
from bs4 import BeautifulSoup # parse HTML files
import time   # time.sleep to pause between requests to the server
import random # randomize the time between requests
import glob # get the list of file names in a directory
from datetime import datetime

# %% [markdown]
# WARNING: The code in this notebook may make changes to existing files in the system.
#
# This notebook is still a work in progress and not yet fully checked for errors. It has been revised many times during the data collection phase and may contain errors.

# %% [markdown]
# ## Get the manufacturer list

# %%
def is_valid_html_text(html_text):
  return 'HTTP 429' not in html_text


def send_request_and_wait(
    url,
    min_sleep_time_seconds=60,
    max_sleep_time_seconds=90,
    max_attempts=10,
    verbose=False
):
  html_text = "HTTP 429"
  attempts = max_attempts
  if verbose:
    print(f"Getting {url}...")
  while not is_valid_html_text(html_text) and attempts > 0:
    sleep_time_seconds = random.randint(min_sleep_time_seconds, max_sleep_time_seconds)
    if verbose:
      print(f"{datetime.now()}: {attempts} attempts remaining. Sleeping for {sleep_time_seconds} seconds...")
    time.sleep(sleep_time_seconds)

    response = requests.get(url)
    html_text = response.text
    attempts -= 1
  if verbose:
    print(f"Done getting {url}!\n")
  return html_text

# %%
def get_brand_list(min_sleep_time_seconds=60, max_sleep_time_seconds=90, max_attempts=10, verbose=True):
  """
  Returns a list of brands and the count of SSDs by each brand from the root page "https://www.techpowerup.com/ssd-specs/"
  """
  # Get the HTML from the root page.
  ROOT_URL = 'https://www.techpowerup.com/ssd-specs/'
  html_root_text = send_request_and_wait(
    ROOT_URL,
    min_sleep_time_seconds=min_sleep_time_seconds,
    max_sleep_time_seconds=max_sleep_time_seconds,
    max_attempts=max_attempts,
    verbose=verbose
  )
  html_root_object = BeautifulSoup(html_root_text, 'html.parser')

  # Get the list of manufacturers and the count of SSDs by each manufacturer.
  div_manufacturer_object = html_root_object.find('div', {'data-title': 'Manufacturer'})
  a_objects = div_manufacturer_object.find_all('a')
  brand_list = []
  # Example 'a' object: <a  href="/ssd-specs/filter/?mfgr=SK Hynix" >SK Hynix <span class="filter-list-item-entry-count">(25)</span></a>
  for a_object in a_objects:
    url_suffix_filtered_by_brand = a_object['href']  # example: '/ssd-specs/filter/?mfgr=SK Hynix'
    brand_name_and_count = a_object.text.strip()  # example: 'SK Hynix (25)'
    brand_name = brand_name_and_count.split('(')[0].strip()  # example: 'SK Hynix'
    ssd_count = brand_name_and_count.split('(')[1][:-1]  # example: '25'
    ssd_count = int(ssd_count)
    brand_list.append((
      url_suffix_filtered_by_brand,
      brand_name,
      ssd_count
    ))

  return brand_list


# manufacturer_list = get_manufacturer_list()
# print(manufacturer_list)

# %% [markdown]
# ## Get the list of URLs for the data pages of all SSDs from each manufacturer

# %%
def get_SSD_data_URLs_from_manufacturer(valid_html_object_by_manufacturer):
  # Example: <a class="drive-capacity" href="/ssd-specs/sk-hynix-bettle-x31-1-tb.d1726" style="white-space: nowrap">1 TB</a>
  a_drive_capacity_objects = valid_html_object_by_manufacturer.find_all('a', {'class': 'drive-capacity'})
  data_URL_set = set()
  for a_drive_capacity_object in a_drive_capacity_objects:
    data_URL = a_drive_capacity_object['href']
    data_URL_set.add(data_URL)
  return data_URL_set

# %%
def get_all_html_file_paths(folder):
  all_html_file_paths = glob.glob(folder + '*.html')
  return all_html_file_paths


def get_brand_name_from_file_path(file_path):
  # Example: "data/manufacturer/SK_Hynix-2024-01-14-14:36:45.html"
  file_name = file_path.split('/')[-1]      # example: "SK_Hynix-2024-01-14-14:36:45.html"
  brand_name = file_name.split('-')[0]      # example: "SK_Hynix"
  brand_name = brand_name.replace('_', ' ') # example: "SK Hynix"
  return brand_name


def get_data_URLs_by_brand(folder='data/manufacturer'):
  """
  Returns a dictionary mapping a brand to a set of data URLs for that brand.
  """
  brand_html_file_paths = get_all_html_file_paths(folder='data/manufacturer/')
  brand_to_data_URLs = dict()
  for brand_html_file_path in brand_html_file_paths:
    with open(brand_html_file_path, 'r') as f:
      html_text = f.read()
    html_object = BeautifulSoup(html_text, 'html.parser')
    if not is_valid_html_text(html_text):
      print(f'Invalid HTML for {brand_html_file_path}')
      continue
    data_URLs = get_SSD_data_URLs_from_manufacturer(valid_html_object_by_manufacturer=html_object)
    brand_name = get_brand_name_from_file_path(brand_html_file_path)
    brand_to_data_URLs[brand_name] = data_URLs
  return brand_to_data_URLs

print(len(get_data_URLs_by_brand()['Acer']))
print(len(get_data_URLs_by_brand()))
# get_data_URLs_by_brand()
# Out:
# 27
# 43

# %%
def download_html_of_queries_by_brand_and_get_data_URLs_by_brand(folder='data/manufacturer'):
  HOMEPAGE_URL = 'https://www.techpowerup.com'
  brand_list = get_brand_list(
    min_sleep_time_seconds=10,
    max_sleep_time_seconds=30,
    max_attempts=10,
    verbose=True
  )
  brand_to_data_URLs = {}
  downloaded_data_urls_by_brand = get_data_URLs_by_brand(folder=folder)

  for url_suffix_filtered_by_brand, brand_name, ssd_count in brand_list:
    brand_name_underscored = brand_name.replace(' ', '_')
    if brand_name in downloaded_data_urls_by_brand:
      print(f'Brand "{brand_name}" already downloaded')
      data_URLs = downloaded_data_urls_by_brand[brand_name]
      brand_to_data_URLs[brand_name] = data_URLs
      continue

    url_filtered_by_brand = HOMEPAGE_URL + url_suffix_filtered_by_brand

    html_text_filtered_by_brand = send_request_and_wait(
      url_filtered_by_brand,
      min_sleep_time_seconds=60,
      max_sleep_time_seconds=90,
      max_attempts=10,
      verbose=True
    )

    if not is_valid_html_text(html_text_filtered_by_brand):
      print(f'Invalid HTML for {brand_name}')
      continue

    html_object_filtered_by_brand = BeautifulSoup(html_text_filtered_by_brand, 'html.parser')
    data_URLs = get_SSD_data_URLs_from_manufacturer(html_object_filtered_by_brand)
    print(f'{brand_name} ({ssd_count}): {len(data_URLs)}')
    # assert len(data_URLs) == ssd_count, \
      # f'Expected {ssd_count} data URLs for {brand_name}, but got {len(data_URLs)} data URLs instead.'
    brand_to_data_URLs[brand_name] = data_URLs

    current_datetime = datetime.now().strftime('%Y-%m-%d-%H:%M:%S')
    with open(f'{folder}/{brand_name_underscored}-{current_datetime}.html', 'w') as f:
      f.write(html_text_filtered_by_brand)
    # break

  print(f'len(brand_to_data_URLs): {len(brand_to_data_URLs)}')
  print(f'len(brand_list): {len(brand_list)}')
  return brand_to_data_URLs


def start_download():
  download_html_of_queries_by_brand_and_get_data_URLs_by_brand()

start_download()
# Out:
# Getting https://www.techpowerup.com/ssd-specs/...
# 2024-01-15 10:13:38.602596: 10 attempts remaining. Sleeping for 28 seconds...
# Done getting https://www.techpowerup.com/ssd-specs/!
#
# Brand "Acer" already downloaded
# Brand "ADATA" already downloaded
# Brand "Addlink" already downloaded
# Brand "AMD" already downloaded
# Brand "Aorus" already downloaded
# Brand "Apacer" already downloaded
# Brand "Apple" already downloaded
# Brand "Asgard" already downloaded
# Brand "Asura" already downloaded
# Brand "ASUS" already downloaded
# Brand "ASUS ROG" already downloaded
# Brand "Biostar" already downloaded
# Brand "CFD Gaming" already downloaded
# Brand "Colorful" already downloaded
# Brand "Corsair" already downloaded
# Brand "Crucial" already downloaded
# Brand "DapuStor" already downloaded
# Brand "Dera" already downloaded
# Brand "Digifast" already downloaded
# Brand "Digma" already downloaded
# Brand "Drevo" already downloaded
# Brand "Enmotus" already downloaded
# Brand "Fanxiang" already downloaded
# Brand "Galax" already downloaded
# Brand "Gigabyte" already downloaded
# Brand "Goodram" already downloaded
# Brand "Hikvision" already downloaded
# Brand "HP" already downloaded
# Brand "HyperX" already downloaded
# Brand "Inland" already downloaded
# Brand "Intel" already downloaded
# Brand "IRDM" already downloaded
# Brand "Kingspec" already downloaded
# Brand "Kingston" already downloaded
# Brand "Kioxia" already downloaded
# Brand "Klevv" already downloaded
# Brand "Kodak" already downloaded
# Brand "Lexar" already downloaded
# Brand "Longsys" already downloaded
# Brand "Magix" already downloaded
# Brand "Mancer" already downloaded
# Brand "Mega Electronics Fastro" already downloaded
# Brand "Memblaze" already downloaded
# Brand "Micron" already downloaded
# Brand "MiWhole" already downloaded
# Brand "MLD" already downloaded
# Brand "Movespeed" already downloaded
# Brand "MSI" already downloaded
# Brand "Mushkin" already downloaded
# Brand "Neo Forza" already downloaded
# Brand "Netac" already downloaded
# Brand "Nextorage" already downloaded
# Brand "OCZ" already downloaded
# Brand "Patriot" already downloaded
# Brand "Phison" already downloaded
# Brand "Pichau" already downloaded
# Brand "Plextor" already downloaded
# Brand "PNY" already downloaded
# Brand "Ramaxel" already downloaded
# Brand "Redragon" already downloaded
# Brand "Reletech" already downloaded
# Brand "RZX" already downloaded
# Brand "Sabrent" already downloaded
# Brand "Samsung" already downloaded
# Brand "SanDisk" already downloaded
# Brand "Seagate" already downloaded
# Brand "Silicon Power" already downloaded
# Brand "SK Hynix" already downloaded
# Brand "Solidigm" already downloaded
# Brand "Sony" already downloaded
# Brand "SSTC" already downloaded
# Brand "Synology" already downloaded
# Brand "Teamgroup" already downloaded
# Brand "TLET" already downloaded
# Brand "Toshiba" already downloaded
# Brand "Transcend" already downloaded
# Brand "Union Memory" already downloaded
# Brand "Valve" already downloaded
# Brand "VisionTek" already downloaded
# Brand "Western Digital" already downloaded
# Brand "Wicgtyp" already downloaded
# Brand "Xbox Series X" already downloaded
# Brand "XPG" already downloaded
# Brand "Xraydisk" already downloaded
# Brand "Zadak" already downloaded
# Brand "Zhitai" already downloaded
# Brand "Zircon" already downloaded
# len(brand_to_data_URLs): 87
# len(brand_list): 87

# %% [markdown]
# ## (WORK IN PROGRESS) Get list of downloaded SSD HTML files and add brand name to the prefix

# %%
def get_downloaded_html_file_paths(html_input_folder='data/html/'):
  """
  Returns a list of paths to the downloaded HTML files.
  """
  downloaded_html_file_paths = glob.glob(html_input_folder + '*.html')
  return downloaded_html_file_paths

def get_new_html_file_paths(html_input_folder='data/html/'):
  """
  Returns a list of paths to the new HTML files.
  """
  downloaded_html_file_paths = get_downloaded_html_file_paths(html_input_folder=html_input_folder)
  new_html_file_paths = []
  manufacturer_list = get_manufacturer_and_count_list()
  for manufacturer_name, ssd_count in manufacturer_list:
    for ssd_index in range(1, ssd_count + 1):
      html_file_name = f'{manufacturer_name}_{ssd_index}.html'
      html_file_path = html_input_folder + html_file_name
      if html_file_path not in downloaded_html_file_paths:
        new_html_file_paths.append(html_file_path)
  return new_html_file_paths

# %% [markdown]
# ### (WORK IN PROGRESS) Get the page of an SSD

# %%
def get_html_object_from_file(html_file_path : str):
    html_object = None
    with open(html_file_path, 'r') as html_file_handle:
        html_text = html_file_handle.read()
        html_object = BeautifulSoup(html_text, 'html.parser')
    return html_object


def is_valid_html(html_object):
    html_text = html_object.get_text()
    # print(html_text)
    return 'HTTP 429' not in html_text


def get_url_from_invalid_html_object(html_object):
    html_object.find('input')['value']


def get_url_from_valid_html_object(html_object):
    html_object.find('meta', {'property': 'og:url'})['content']


def get_url_suffix_from_full_url(url : str):
    # https://www.techpowerup.com/ssd-specs/xpg-sx8200-pro-256-gb.d882
    # Remove 'https://www.techpowerup.com'
    url_suffix = url[28:]
    # Remove '/ssd-specs/'
    url_suffix = url_suffix[10:]
    return url_suffix


def get_url_suffix_from_partial_url(url : str):
    # /ssd-specs/xpg-sx8200-pro-256-gb.d882
    # Remove '/ssd-specs/'
    url_suffix = url[10:]
    return url_suffix


def get_url_suffix_from_html_file_path(html_file_path : str):
    # print(html_file_path)
    url_suffix = html_file_path[10:]    # Remove 'ssd_htmls/'
    # print(url_suffix)
    url_suffix = url_suffix[11:]        # Remove the '_ssd-specs_'
    # print(url_suffix)
    url_suffix = url_suffix[:-25]   # Remove the datetime suffix
    # print(url_suffix)
    # print()
    return url_suffix


def categorise_html_urls(
    html_file_paths : list,
    valid_html_url_suffixes : dict,
    invalid_html_url_suffixes : dict
):
    for html_file_path in html_file_paths:
        url_suffix = get_url_suffix_from_html_file_path(html_file_path)
        html_object = get_html_object_from_file(html_file_path)
        if is_valid_html(html_object):
            # print(html_file_path)
            html_url = get_url_from_valid_html_object(html_object)
            valid_html_url_suffixes.add(url_suffix)
        else:
            html_url = get_url_from_invalid_html_object(html_object)
            invalid_html_url_suffixes.add(url_suffix)


def get_html_file_paths(html_files_folder):
    html_file_paths = glob.glob(html_files_folder + '*.html')
    # pprint.pprint(html_file_paths)
    return html_file_paths


def get_invalid_html_urls_file_path():
    current_date_time = datetime.now().strftime('%Y-%m-%d-%H-%M-%S')
    invalid_htmls_urls_file_path = f'invalid_htmls_urls-{current_date_time}.txt'
    return invalid_htmls_urls_file_path


def get_valid_htmls_new_folder_path():
    # current_date_time = datetime.now().strftime('%Y-%m-%d-%H-%M-%S')
    valid_htmls_new_folder_path = f'valid_htmls-2/'
    return valid_htmls_new_folder_path


def copy_latest_valid_htmls_to_new_folder(
    valid_html_url_suffixes : set
):
    valid_htmls_new_folder_path = get_valid_htmls_new_folder_path()
    html_file_paths = get_html_file_paths(html_files_folder='data/html/')
    for html_file_path in html_file_paths:
        url_suffix = get_url_suffix_from_html_file_path(html_file_path)
        if url_suffix in valid_html_url_suffixes:
            url_suffix_without_dot = url_suffix.replace('.', '-')
            new_file_path = valid_htmls_new_folder_path + url_suffix_without_dot + '.html'
            shutil.copy(
                html_file_path,
                new_file_path
            )
            # Remove from valid_html_url_suffixes
            valid_html_url_suffixes.remove(url_suffix)



def check_all_htmls_and_record_urls_to_redownload(
    html_file_paths : list,
    invalid_htmls_urls_file_path : str
):
    valid_html_url_suffixes = set()
    invalid_html_url_suffixes = set()
    categorise_html_urls(
        html_file_paths,
        valid_html_url_suffixes,
        invalid_html_url_suffixes
    )
    # pprint.pprint(valid_html_url_suffixes)
    # pprint.pprint(invalid_html_url_suffixes)
    copy_latest_valid_htmls_to_new_folder(
        valid_html_url_suffixes
    )
    invalid_html_url_suffixes = invalid_html_url_suffixes - valid_html_url_suffixes
    print(f'Number of valid htmls: {len(valid_html_url_suffixes)}')
    print(f'Number of invalid htmls: {len(invalid_html_url_suffixes)}')
    return
    with open(invalid_htmls_urls_file_path, 'w') as invalid_htmls_urls_file_handle:
        for invalid_html_url_suffix in invalid_html_url_suffixes:
            # print(invalid_html_url_suffix)
            invalid_htmls_urls_file_handle.write(invalid_html_url_suffix + '\n')


def check_all_htmls():
    html_file_paths = get_html_file_paths(html_files_folder='data/html/')
    invalid_htmls_urls_file_path = get_invalid_html_urls_file_path()
    check_all_htmls_and_record_urls_to_redownload(
        html_file_paths,
        invalid_htmls_urls_file_path
    )


# check_all_htmls()

# %%
def send_request_and_wait(url : str, min_wait_time_seconds=30, max_wait_time_seconds=60):
    html_text = 'HTTP 429'
    print(f'Getting {url}...')
    while 'HTTP 429' in html_text:
        wait_time_seconds = random.randint(min_wait_time_seconds, max_wait_time_seconds)
        print(f'Waiting {wait_time_seconds} seconds...')
        time.sleep(wait_time_seconds)
        response = requests.get(url)
        html_text = response.text
        response.close()
    return html_text



def redownload_failed_attempts(failed_urls_suffixes : list):
    # counter = 0
    for i, url_suffix in enumerate(failed_urls_suffixes):
        if i < 249:
            continue
        url = f'https://www.techpowerup.com/ssd-specs/{url_suffix}'
        html_text = send_request_and_wait(url)
        # counter += 1
        print(f'Got {i+1} : {url_suffix}!\n')
        # Write to file
        url_suffix_without_dot = url_suffix.replace('.', '-')
        html_file_path = f'ssd_htmls-try-1/{url_suffix_without_dot}.html'
        with open(html_file_path, 'w') as html_file_handle:
            html_file_handle.write(html_text)


def redownload():
    invalid_htmls_url_file_path = 'invalid_htmls_urls-2024-01-01-12-52-14.txt'
    failed_urls_suffixes = []
    with open(invalid_htmls_url_file_path, 'r') as invalid_htmls_urls_file_handle:
        for line in invalid_htmls_urls_file_handle:
            url_suffix = line.strip()
            failed_urls_suffixes.append(url_suffix)
    redownload_failed_attempts(failed_urls_suffixes)

redownload()
# Out:
# Getting https://www.techpowerup.com/ssd-specs/reletech-p400-evo-500-gb.d1515...
# Waiting 58 seconds...
# Got 250 : reletech-p400-evo-500-gb.d1515!
#
# Getting https://www.techpowerup.com/ssd-specs/micron-9300-pro-3-8-tb.d1286...
# Waiting 48 seconds...
# Got 251 : micron-9300-pro-3-8-tb.d1286!
#
# Getting https://www.techpowerup.com/ssd-specs/kingston-kc2000-500-gb.d278...
# Waiting 32 seconds...
# Got 252 : kingston-kc2000-500-gb.d278!
#
# Getting https://www.techpowerup.com/ssd-specs/dapustor-haishen3-h3100-6-tb.d1650...
# Waiting 56 seconds...
# Got 253 : dapustor-haishen3-h3100-6-tb.d1650!
#
# Getting https://www.techpowerup.com/ssd-specs/kingston-kc2500-250-gb.d262...
# Waiting 49 seconds...
# Got 254 : kingston-kc2500-250-gb.d262!
#
# Getting https://www.techpowerup.com/ssd-specs/kodak-x100-120-gb.d1072...
# Waiting 50 seconds...
# Got 255 : kodak-x100-120-gb.d1072!
#
# Getting https://www.techpowerup.com/ssd-specs/dera-d7436-7-5-tb.d1690...
# Waiting 56 seconds...
# Got 256 : dera-d7436-7-5-tb.d1690!
#
# Getting https://www.techpowerup.com/ssd-specs/crucial-m4-256-gb.d1289...
# Waiting 43 seconds...
# Got 257 : crucial-m4-256-gb.d1289!
#
# Getting https://www.techpowerup.com/ssd-specs/kingspec-xg7000-pro-512-gb.d1417...
# Waiting 48 seconds...
# Got 258 : kingspec-xg7000-pro-512-gb.d1417!
#
# Getting https://www.techpowerup.com/ssd-specs/aorus-gen4-aic-ssd-2-tb.d794...
# Waiting 34 seconds...
# Got 259 : aorus-gen4-aic-ssd-2-tb.d794!
#
# Getting https://www.techpowerup.com/ssd-specs/addlink-s90-lite-512-gb.d1441...
# Waiting 32 seconds...
# Got 260 : addlink-s90-lite-512-gb.d1441!
#
# Getting https://www.techpowerup.com/ssd-specs/adata-ultimate-su630-1-9-tb.d270...
# Waiting 50 seconds...
# Got 261 : adata-ultimate-su630-1-9-tb.d270!
#
# Getting https://www.techpowerup.com/ssd-specs/corsair-mp600-2-tb.d374...
# Waiting 56 seconds...
# Got 262 : corsair-mp600-2-tb.d374!
#
# Getting https://www.techpowerup.com/ssd-specs/adata-ultimate-su630-960-gb.d276...
# Waiting 52 seconds...
# Got 263 : adata-ultimate-su630-960-gb.d276!
#
# Getting https://www.techpowerup.com/ssd-specs/addlink-s91-1-tb.d1546...
# Waiting 41 seconds...
# Got 264 : addlink-s91-1-tb.d1546!
#
# Getting https://www.techpowerup.com/ssd-specs/fanxiang-s500-pro-1-tb.d1438...
# Waiting 59 seconds...
# Got 265 : fanxiang-s500-pro-1-tb.d1438!
#
# Getting https://www.techpowerup.com/ssd-specs/phison-e26-engineering-sample-2-tb.d832...
# Waiting 59 seconds...
# Got 266 : phison-e26-engineering-sample-2-tb.d832!
#
# Getting https://www.techpowerup.com/ssd-specs/reletech-p400-evo-1-tb.d1517...
# Waiting 39 seconds...
# Got 267 : reletech-p400-evo-1-tb.d1517!
#
# Getting https://www.techpowerup.com/ssd-specs/kodak-x100-960-gb.d1079...
# Waiting 36 seconds...
# Got 268 : kodak-x100-960-gb.d1079!
#
# Getting https://www.techpowerup.com/ssd-specs/lexar-nm610-pro-1-tb.d1596...
# Waiting 50 seconds...
# Got 269 : lexar-nm610-pro-1-tb.d1596!
#
# Getting https://www.techpowerup.com/ssd-specs/netac-nv5000-2-tb.d1020...
# Waiting 37 seconds...
# Got 270 : netac-nv5000-2-tb.d1020!
#
# Getting https://www.techpowerup.com/ssd-specs/hp-s700-pro-256-gb.d420...
# Waiting 33 seconds...
# Got 271 : hp-s700-pro-256-gb.d420!
#
# Getting https://www.techpowerup.com/ssd-specs/crucial-mx300-1-tb.d82...
# Waiting 38 seconds...
# Got 272 : crucial-mx300-1-tb.d82!
#
# Getting https://www.techpowerup.com/ssd-specs/adata-ultimate-su630-240-gb.d994...
# Waiting 36 seconds...
# Got 273 : adata-ultimate-su630-240-gb.d994!
#
# Getting https://www.techpowerup.com/ssd-specs/crucial-mx300-275-gb.d79...
# Waiting 60 seconds...
# Got 274 : crucial-mx300-275-gb.d79!
#
# Getting https://www.techpowerup.com/ssd-specs/dera-d7436-3-8-tb.d1689...
# Waiting 31 seconds...
# Got 275 : dera-d7436-3-8-tb.d1689!
#
# Getting https://www.techpowerup.com/ssd-specs/lexar-nm610-pro-500-gb.d1595...
# Waiting 55 seconds...
# Got 276 : lexar-nm610-pro-500-gb.d1595!
#
# Getting https://www.techpowerup.com/ssd-specs/corsair-mp600-gs-2-tb.d1218...
# Waiting 58 seconds...
# Got 277 : corsair-mp600-gs-2-tb.d1218!
#
# Getting https://www.techpowerup.com/ssd-specs/plextor-m10p-g-1-tb.d677...
# Waiting 33 seconds...
# Got 278 : plextor-m10p-g-1-tb.d677!
#
# Getting https://www.techpowerup.com/ssd-specs/samsung-470-series-256-gb.d1260...
# Waiting 38 seconds...
# Got 279 : samsung-470-series-256-gb.d1260!
#
# Getting https://www.techpowerup.com/ssd-specs/corsair-mp510-480-gb.d376...
# Waiting 40 seconds...
# Got 280 : corsair-mp510-480-gb.d376!
#
# Getting https://www.techpowerup.com/ssd-specs/corsair-mp600-500-gb.d372...
# Waiting 32 seconds...
# Got 281 : corsair-mp600-500-gb.d372!
#
# Getting https://www.techpowerup.com/ssd-specs/plextor-m10e-256-gb.d686...
# Waiting 37 seconds...
# Got 282 : plextor-m10e-256-gb.d686!
#
# Getting https://www.techpowerup.com/ssd-specs/kioxia-exceria-g2-2-tb.d1340...
# Waiting 38 seconds...
# Got 283 : kioxia-exceria-g2-2-tb.d1340!
#
# Getting https://www.techpowerup.com/ssd-specs/adata-ultimate-su630-1-9-tb.d997...
# Waiting 57 seconds...
# Got 284 : adata-ultimate-su630-1-9-tb.d997!
#
# Getting https://www.techpowerup.com/ssd-specs/kingston-kc600-256-gb.d291...
# Waiting 44 seconds...
# Got 285 : kingston-kc600-256-gb.d291!
#
# Getting https://www.techpowerup.com/ssd-specs/patriot-viper-vpn100-1-tb.d1027...
# Waiting 53 seconds...
# Got 286 : patriot-viper-vpn100-1-tb.d1027!
#
# Getting https://www.techpowerup.com/ssd-specs/micron-9300-pro-15-tb.d1287...
# Waiting 31 seconds...
# Got 287 : micron-9300-pro-15-tb.d1287!
#
# Getting https://www.techpowerup.com/ssd-specs/adata-se900g-1-tb.d1136...
# Waiting 43 seconds...
# Got 288 : adata-se900g-1-tb.d1136!
#
# Getting https://www.techpowerup.com/ssd-specs/plextor-m10p-y-512-gb.d680...
# Waiting 55 seconds...
# Got 289 : plextor-m10p-y-512-gb.d680!
#
# Getting https://www.techpowerup.com/ssd-specs/hp-fx900-1-tb.d813...
# Waiting 52 seconds...
# Got 290 : hp-fx900-1-tb.d813!
#
# Getting https://www.techpowerup.com/ssd-specs/crucial-bx500-1-tb.d1180...
# Waiting 43 seconds...
# Got 291 : crucial-bx500-1-tb.d1180!
#
# Getting https://www.techpowerup.com/ssd-specs/sabrent-rocket-4-0-500-gb.d549...
# Waiting 60 seconds...
# Got 292 : sabrent-rocket-4-0-500-gb.d549!
#
# Getting https://www.techpowerup.com/ssd-specs/kingston-kc400-512-gb.d306...
# Waiting 56 seconds...
# Got 293 : kingston-kc400-512-gb.d306!
#
# Getting https://www.techpowerup.com/ssd-specs/msi-spatium-m370-1-tb.d572...
# Waiting 59 seconds...
# Waiting 52 seconds...
# Waiting 57 seconds...
# Waiting 36 seconds...
# Waiting 58 seconds...
# Waiting 36 seconds...
# Waiting 56 seconds...
# Waiting 60 seconds...
# Waiting 39 seconds...
# Waiting 57 seconds...
# Waiting 51 seconds...
# Waiting 39 seconds...
# Waiting 37 seconds...
# Waiting 46 seconds...
# Waiting 52 seconds...
# Waiting 39 seconds...
# Waiting 51 seconds...
# Waiting 33 seconds...
# Waiting 30 seconds...
# Waiting 54 seconds...
# Waiting 51 seconds...
# Waiting 36 seconds...
# Waiting 52 seconds...
# Waiting 41 seconds...
# Got 294 : msi-spatium-m370-1-tb.d572!
#
# Getting https://www.techpowerup.com/ssd-specs/miwhole-ct200-1-tb.d1504...
# Waiting 30 seconds...
# Got 295 : miwhole-ct200-1-tb.d1504!
#
# Getting https://www.techpowerup.com/ssd-specs/goodram-px500-1-tb.d1384...
# Waiting 58 seconds...
# Got 296 : goodram-px500-1-tb.d1384!
#
# Getting https://www.techpowerup.com/ssd-specs/samsung-860-evo-4-tb.d10...
# Waiting 55 seconds...
# Got 297 : samsung-860-evo-4-tb.d10!
#
# Getting https://www.techpowerup.com/ssd-specs/goodram-px500-512-gb.d1385...
# Waiting 58 seconds...
# Got 298 : goodram-px500-512-gb.d1385!
#
# Getting https://www.techpowerup.com/ssd-specs/hikvision-e100n-512-gb.d1401...
# Waiting 30 seconds...
# Got 299 : hikvision-e100n-512-gb.d1401!
#
# Getting https://www.techpowerup.com/ssd-specs/kingston-kc600-2-tb.d294...
# Waiting 41 seconds...
# Waiting 45 seconds...
# Waiting 38 seconds...
# Waiting 34 seconds...
# Waiting 43 seconds...
# Waiting 55 seconds...
# Waiting 51 seconds...
# Got 300 : kingston-kc600-2-tb.d294!
#
# Getting https://www.techpowerup.com/ssd-specs/lexar-ares-2-tb.d1478...
# Waiting 52 seconds...
# Got 301 : lexar-ares-2-tb.d1478!
#
# Getting https://www.techpowerup.com/ssd-specs/dapustor-haishen3-h3100-3-tb.d1649...
# Waiting 41 seconds...
# Got 302 : dapustor-haishen3-h3100-3-tb.d1649!
#
# Getting https://www.techpowerup.com/ssd-specs/adata-ultimate-su630-960-gb.d996...
# Waiting 34 seconds...
# Got 303 : adata-ultimate-su630-960-gb.d996!
#
# Getting https://www.techpowerup.com/ssd-specs/klevv-cras-c930-1-tb.d1196...
# Waiting 44 seconds...
# Got 304 : klevv-cras-c930-1-tb.d1196!
#
# Getting https://www.techpowerup.com/ssd-specs/msi-spatium-m470-1-tb.d564...
# Waiting 47 seconds...
# Got 305 : msi-spatium-m470-1-tb.d564!
#
# Getting https://www.techpowerup.com/ssd-specs/samsung-860-evo-1-tb.d8...
# Waiting 44 seconds...
# Got 306 : samsung-860-evo-1-tb.d8!
#
# Getting https://www.techpowerup.com/ssd-specs/adata-premium-ssd-for-ps5-2-tb.d1351...
# Waiting 44 seconds...
# Got 307 : adata-premium-ssd-for-ps5-2-tb.d1351!
#
# Getting https://www.techpowerup.com/ssd-specs/hikvision-hiksemi-cc700-512-gb.d1243...
# Waiting 31 seconds...
# Waiting 59 seconds...
# Got 308 : hikvision-hiksemi-cc700-512-gb.d1243!
#
# Getting https://www.techpowerup.com/ssd-specs/kingston-kc2500-500-gb.d263...
# Waiting 42 seconds...
# Got 309 : kingston-kc2500-500-gb.d263!
#
# Getting https://www.techpowerup.com/ssd-specs/kingston-kc3000-512-gb.d258...
# Waiting 49 seconds...
# Got 310 : kingston-kc3000-512-gb.d258!
#
# Getting https://www.techpowerup.com/ssd-specs/micron-2400-512-gb.d808...
# Waiting 46 seconds...
# Got 311 : micron-2400-512-gb.d808!
#
# Getting https://www.techpowerup.com/ssd-specs/colorful-cn700-1-tb.d1181...
# Waiting 57 seconds...
# Got 312 : colorful-cn700-1-tb.d1181!
#
# Getting https://www.techpowerup.com/ssd-specs/addlink-x70-rgb-256-gb.d339...
# Waiting 51 seconds...
# Got 313 : addlink-x70-rgb-256-gb.d339!
#
# Getting https://www.techpowerup.com/ssd-specs/adata-se900g-512-gb.d1134...
# Waiting 48 seconds...
# Got 314 : adata-se900g-512-gb.d1134!
#
# Getting https://www.techpowerup.com/ssd-specs/patriot-burst-240-gb.d645...
# Waiting 59 seconds...
# Got 315 : patriot-burst-240-gb.d645!
#
# Getting https://www.techpowerup.com/ssd-specs/hikvision-e100n-128-gb.d1400...
# Waiting 49 seconds...
# Got 316 : hikvision-e100n-128-gb.d1400!
#
# Getting https://www.techpowerup.com/ssd-specs/reletech-p400-256-gb.d1317...
# Waiting 54 seconds...
# Got 317 : reletech-p400-256-gb.d1317!
#
# Getting https://www.techpowerup.com/ssd-specs/kioxia-xg8-4-tb.d1052...
# Waiting 36 seconds...
# Got 318 : kioxia-xg8-4-tb.d1052!
#
# Getting https://www.techpowerup.com/ssd-specs/aorus-gen4-7000s-ssd-1-tb.d404...
# Waiting 30 seconds...
# Got 319 : aorus-gen4-7000s-ssd-1-tb.d404!
#
# Getting https://www.techpowerup.com/ssd-specs/ocz-vector-460-120-gb.d1300...
# Waiting 48 seconds...
# Got 320 : ocz-vector-460-120-gb.d1300!
#
# Getting https://www.techpowerup.com/ssd-specs/adata-swordfish-250-gb.d141...
# Waiting 45 seconds...
# Got 321 : adata-swordfish-250-gb.d141!
#
# Getting https://www.techpowerup.com/ssd-specs/reletech-p400-pro-tlc-500-gb.d847...
# Waiting 37 seconds...
# Got 322 : reletech-p400-pro-tlc-500-gb.d847!
#
# Getting https://www.techpowerup.com/ssd-specs/neo-forza-nfp495-2-tb.d1708...
# Waiting 46 seconds...
# Got 323 : neo-forza-nfp495-2-tb.d1708!
#
# Getting https://www.techpowerup.com/ssd-specs/klevv-cras-c910-1-tb.d1197...
# Waiting 55 seconds...
# Got 324 : klevv-cras-c910-1-tb.d1197!
#
# Getting https://www.techpowerup.com/ssd-specs/mushkin-pilot-e-1-tb.d773...
# Waiting 32 seconds...
# Got 325 : mushkin-pilot-e-1-tb.d773!
#
# Getting https://www.techpowerup.com/ssd-specs/crucial-t700-1-tb.d1463...
# Waiting 44 seconds...
# Got 326 : crucial-t700-1-tb.d1463!
#
# Getting https://www.techpowerup.com/ssd-specs/patriot-viper-vpn100-512-gb.d626...
# Waiting 53 seconds...
# Got 327 : patriot-viper-vpn100-512-gb.d626!
#
# Getting https://www.techpowerup.com/ssd-specs/micron-2550-512-gb.d1281...
# Waiting 42 seconds...
# Got 328 : micron-2550-512-gb.d1281!
#
# Getting https://www.techpowerup.com/ssd-specs/netac-nv3000-rgb-1-tb.d750...
# Waiting 34 seconds...
# Got 329 : netac-nv3000-rgb-1-tb.d750!
#
# Getting https://www.techpowerup.com/ssd-specs/sabrent-rocket-4-plus-500-gb.d1016...
# Waiting 33 seconds...
# Got 330 : sabrent-rocket-4-plus-500-gb.d1016!
#
# Getting https://www.techpowerup.com/ssd-specs/dapustor-haishen3-h3000-8-tb.d1645...
# Waiting 47 seconds...
# Got 331 : dapustor-haishen3-h3000-8-tb.d1645!
#
# Getting https://www.techpowerup.com/ssd-specs/irdm-pro-m-2-ssd-2-tb.d780...
# Waiting 30 seconds...
# Got 332 : irdm-pro-m-2-ssd-2-tb.d780!
#
# Getting https://www.techpowerup.com/ssd-specs/netac-nv3000-250-gb.d748...
# Waiting 44 seconds...
# Got 333 : netac-nv3000-250-gb.d748!
#
# Getting https://www.techpowerup.com/ssd-specs/goodram-px500-512-gb.d1387...
# Waiting 42 seconds...
# Got 334 : goodram-px500-512-gb.d1387!
#
# Getting https://www.techpowerup.com/ssd-specs/aorus-gen4-ssd-v2-512-gb.d402...
# Waiting 41 seconds...
# Got 335 : aorus-gen4-ssd-v2-512-gb.d402!
#
# Getting https://www.techpowerup.com/ssd-specs/adata-swordfish-2-tb.d144...
# Waiting 57 seconds...
# Got 336 : adata-swordfish-2-tb.d144!
#
# Getting https://www.techpowerup.com/ssd-specs/sabrent-rocket-4-plus-g-2-tb.d855...
# Waiting 36 seconds...
# Got 337 : sabrent-rocket-4-plus-g-2-tb.d855!
#
# Getting https://www.techpowerup.com/ssd-specs/kingston-kc3000-1-tb.d259...
# Waiting 59 seconds...
# Got 338 : kingston-kc3000-1-tb.d259!
#
# Getting https://www.techpowerup.com/ssd-specs/kioxia-xg8-1-tb.d1054...
# Waiting 52 seconds...
# Got 339 : kioxia-xg8-1-tb.d1054!
#
# Getting https://www.techpowerup.com/ssd-specs/intel-x25-m-g2-160-gb.d1296...
# Waiting 47 seconds...
# Got 340 : intel-x25-m-g2-160-gb.d1296!
#
# Getting https://www.techpowerup.com/ssd-specs/pny-lx3030-2-tb.d789...
# Waiting 57 seconds...
# Got 341 : pny-lx3030-2-tb.d789!
#
# Getting https://www.techpowerup.com/ssd-specs/samsung-850-evo-2-tb.d32...
# Waiting 54 seconds...
# Got 342 : samsung-850-evo-2-tb.d32!
#
# Getting https://www.techpowerup.com/ssd-specs/lexar-nm600-480-gb.d593...
# Waiting 36 seconds...
# Got 343 : lexar-nm600-480-gb.d593!
#
# Getting https://www.techpowerup.com/ssd-specs/irdm-cx400-gen-2-256-gb.d1383...
# Waiting 36 seconds...
# Waiting 37 seconds...
# Waiting 35 seconds...
# Waiting 49 seconds...
# Waiting 35 seconds...
# Waiting 36 seconds...
# Waiting 56 seconds...
# Waiting 31 seconds...
# Waiting 52 seconds...
# Waiting 52 seconds...
# Waiting 46 seconds...
# Waiting 51 seconds...
# Waiting 59 seconds...
# Waiting 36 seconds...
# Waiting 43 seconds...
# Waiting 41 seconds...
# Waiting 33 seconds...
# Waiting 32 seconds...
# Waiting 58 seconds...
# Waiting 47 seconds...
# Waiting 59 seconds...
# Waiting 57 seconds...
# Waiting 32 seconds...
# Waiting 60 seconds...
# Got 344 : irdm-cx400-gen-2-256-gb.d1383!
#
# Getting https://www.techpowerup.com/ssd-specs/hikvision-hiksemi-future-512-gb.d1555...
# Waiting 40 seconds...
# Got 345 : hikvision-hiksemi-future-512-gb.d1555!
#
# Getting https://www.techpowerup.com/ssd-specs/adata-ultimate-su630-240-gb.d268...
# Waiting 53 seconds...
# Got 346 : adata-ultimate-su630-240-gb.d268!
#
# Getting https://www.techpowerup.com/ssd-specs/sabrent-rocket-4-plus-1-tb.d544...
# Waiting 34 seconds...
# Got 347 : sabrent-rocket-4-plus-1-tb.d544!
#
# Getting https://www.techpowerup.com/ssd-specs/hikvision-c100-240-gb.d1338...
# Waiting 48 seconds...
# Got 348 : hikvision-c100-240-gb.d1338!
#
# Getting https://www.techpowerup.com/ssd-specs/klevv-cras-c910-500-gb.d1198...
# Waiting 48 seconds...
# Got 349 : klevv-cras-c910-500-gb.d1198!
#
# Getting https://www.techpowerup.com/ssd-specs/micron-2550-256-gb.d1282...
# Waiting 37 seconds...
# Waiting 39 seconds...
# Waiting 51 seconds...
# Waiting 44 seconds...
# Waiting 38 seconds...
# Waiting 60 seconds...
# Waiting 31 seconds...
# Got 350 : micron-2550-256-gb.d1282!
#
# Getting https://www.techpowerup.com/ssd-specs/netac-nv5000-1-tb.d1727...
# Waiting 40 seconds...
# Waiting 47 seconds...
# Got 351 : netac-nv5000-1-tb.d1727!
#
# Getting https://www.techpowerup.com/ssd-specs/lexar-nm800-pro-w-heatsink-512-gb.d873...
# Waiting 55 seconds...
# Got 352 : lexar-nm800-pro-w-heatsink-512-gb.d873!
#
# Getting https://www.techpowerup.com/ssd-specs/kingston-kc400-128-gb.d304...
# Waiting 30 seconds...
# Got 353 : kingston-kc400-128-gb.d304!
#
# Getting https://www.techpowerup.com/ssd-specs/netac-n930e-pro-256-gb.d1173...
# Waiting 40 seconds...
# Got 354 : netac-n930e-pro-256-gb.d1173!
#
# Getting https://www.techpowerup.com/ssd-specs/micron-9400-max-13-tb.d1498...
# Waiting 57 seconds...
# Got 355 : micron-9400-max-13-tb.d1498!
#
# Getting https://www.techpowerup.com/ssd-specs/intel-ssd-750-400-gb.d440...
# Waiting 55 seconds...
# Got 356 : intel-ssd-750-400-gb.d440!
#
# Getting https://www.techpowerup.com/ssd-specs/corsair-mp400-2-tb.d381...
# Waiting 49 seconds...
# Got 357 : corsair-mp400-2-tb.d381!
#
# Getting https://www.techpowerup.com/ssd-specs/adata-ultimate-su630-480-gb.d269...
# Waiting 33 seconds...
# Got 358 : adata-ultimate-su630-480-gb.d269!
#
# Getting https://www.techpowerup.com/ssd-specs/samsung-980-pro-500-gb.d46...
# Waiting 32 seconds...
# Got 359 : samsung-980-pro-500-gb.d46!
#
# Getting https://www.techpowerup.com/ssd-specs/crucial-bx200-960-gb.d101...
# Waiting 51 seconds...
# Got 360 : crucial-bx200-960-gb.d101!
#
# Getting https://www.techpowerup.com/ssd-specs/addlink-s91-512-gb.d1547...
# Waiting 48 seconds...
# Got 361 : addlink-s91-512-gb.d1547!
#
# Getting https://www.techpowerup.com/ssd-specs/kingston-kc2000-250-gb.d272...
# Waiting 57 seconds...
# Got 362 : kingston-kc2000-250-gb.d272!
#
# Getting https://www.techpowerup.com/ssd-specs/crucial-mx100-512-gb.d89...
# Waiting 55 seconds...
# Got 363 : crucial-mx100-512-gb.d89!
#
# Getting https://www.techpowerup.com/ssd-specs/intel-dc-s3510-480-gb.d1762...
# Waiting 58 seconds...
# Got 364 : intel-dc-s3510-480-gb.d1762!
#
# Getting https://www.techpowerup.com/ssd-specs/pichau-aldrin-pro-1-tb.d1765...
# Waiting 56 seconds...
# Got 365 : pichau-aldrin-pro-1-tb.d1765!
#
# Getting https://www.techpowerup.com/ssd-specs/micron-9400-pro-7-5-tb.d1320...
# Waiting 30 seconds...
# Got 366 : micron-9400-pro-7-5-tb.d1320!
#
# Getting https://www.techpowerup.com/ssd-specs/crucial-mx500-250-gb.d932...
# Waiting 38 seconds...
# Waiting 43 seconds...
# Got 367 : crucial-mx500-250-gb.d932!
#
# Getting https://www.techpowerup.com/ssd-specs/netac-n930e-pro-1-tb.d1171...
# Waiting 32 seconds...
# Got 368 : netac-n930e-pro-1-tb.d1171!
#
# Getting https://www.techpowerup.com/ssd-specs/neo-forza-nfp455-4-tb.d1712...
# Waiting 59 seconds...
# Got 369 : neo-forza-nfp455-4-tb.d1712!
#
# Getting https://www.techpowerup.com/ssd-specs/addlink-s95-2-tb.d341...
# Waiting 35 seconds...
# Got 370 : addlink-s95-2-tb.d341!
